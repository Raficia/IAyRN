# %% [markdown]
# **Actividad 3: Solución de problemas.**
# **Nombre:** Rafael Medellín García
# **Matrícula:** 2001626
# **Hora Clase:** Martes N4-N6

# %%
# Librerías a utilizar
import matplotlib.pyplot as plt # generar gráficos
import numpy as np # generar arreglos
import pandas as pd # cargar conjuntos de datos externos
import sklearn.linear_model # contiene diferentes modelos de ML

# %%
plt.xlabel("Horas de estudio")
plt.ylabel("Calificaciones")
plt.scatter(horas_estudio, calificaciones)

# %%
np.random.seed(0)
horas_estudio = np.random.rand(100, 1) * 10
calificaciones = 2 * horas_estudio + np.random.randn(100,1) * 2

# %%
from sklearn.model_selection import train_test_split

train_data, test_data, train_labels, test_labels = train_test_split(horas_estudio, calificaciones, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(train_data, train_labels)
# Out:
# LinearRegression()

# %%
prediccion = model.predict(test_data)

# %%
plt.scatter(train_data, train_labels, color='blue', label='Datos de entrenamiento')
plt.scatter(test_data, test_labels, color='red', label='Datos de prueba')
plt.plot(test_data, prediccion, color='green', linewidth=3, label='Modelo de regresión lineal')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificaciones')
plt.title('Modelo de Regresión Lineal')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(test_labels, prediccion)
print("Error Cuadrático Medio:", mse)
# Out:
# Error Cuadrático Medio: 4.17373352627807
